# %% [markdown]
# <a href="https://colab.research.google.com/github/lresendao/Data_Science/blob/Graficos-Visualizacao-e-Dashboards/Grafico3D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # Importa suporte para gráficos 3D
import pandas as pd

# %%
base = pd.read_csv('orchard.csv')
base.head()
# Out:
#    decrease  rowpos  colpos treatment
# 0        57       1       1         D
# 1        95       2       1         E
# 2         8       3       1         B
# 3        69       4       1         H
# 4        92       5       1         G

# %%
# Verifique se 'base' está corretamente definido
print(base.head())  # Apenas para depuração

# Criando a figura e o eixo 3D
figura = plt.figure(figsize=(8, 6))  # Define o tamanho da figura
eixo = figura.add_subplot(111, projection='3d')  # Alternativa para (1,1,1)

# Criando o scatter plot 3D
eixo.scatter(base['decrease'], base['rowpos'], base['colpos'], c='r', marker='o')

# Configurando rótulos dos eixos
eixo.set_xlabel('Decrease')
eixo.set_ylabel('Rowpos')
eixo.set_zlabel('Colpos')

plt.show()  # Exibe o gráfico
# Out:
#    decrease  rowpos  colpos treatment
# 0        57       1       1         D
# 1        95       2       1         E
# 2         8       3       1         B
# 3        69       4       1         H
# 4        92       5       1         G
