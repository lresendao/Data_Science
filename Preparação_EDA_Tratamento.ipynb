# %% [markdown]
# <a href="https://colab.research.google.com/github/lresendao/Data_Science/blob/main/Prepara%C3%A7%C3%A3o_EDA_Tratamento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as srn
import statistics as sts

# %%
#importar dados
dataset = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Udemy/Prática em Python - Limpeza e Tratamento de Dados/Churn.csv", sep=";")
#visualizar
dataset.head()
# Out:
#    X0   X1  X2        X3  X4  X4.1        X6  X7  X8  X9         X10  X11
# 0   1  619  RS  Feminino  42     2         0   1   1   1  10134888.0    1
# 1   2  608  SC  Feminino  41     1   8380786   1   0   1  11254258.0    0
# 2   3  502  RS  Feminino  42     8   1596608   3   1   0  11393157.0    1
# 3   4  699  RS  Feminino  39     1         0   2   0   0   9382663.0    0
# 4   5  850  SC  Feminino  43     2  12551082   1   1   1    790841.0    0

# %%
#tamanho
dataset.shape
# Out:
# (999, 12)

# %%
#primeiro problema é dar nome as colunas
dataset.columns = ["ID", "Score", "Estado", "Genero", "Idade", "Patrimonio", "Saldo", "Produtos", "TemCartCredito", "Ativo", "Salario", "Saiu"]

# %%
#visualizar
dataset.head()
# Out:
#    ID  Score Estado    Genero  Idade  Patrimonio     Saldo  Produtos  \
# 0   1    619     RS  Feminino     42           2         0         1
# 1   2    608     SC  Feminino     41           1   8380786         1
# 2   3    502     RS  Feminino     42           8   1596608         3
# 3   4    699     RS  Feminino     39           1         0         2
# 4   5    850     SC  Feminino     43           2  12551082         1
#
#    TemCartCredito  Ativo     Salario  Saiu
# 0               1      1  10134888.0     1
# 1               0      1  11254258.0     0
# 2               1      0  11393157.0     1
# 3               0      0   9382663.0     0
# 4               1      1    790841.0     0

# %%
#explorar dados categóricos
#estado
agrupado = dataset.groupby(["Estado"]).size()

agrupado
# Out:
# Estado
# PR    257
# RP      1
# RS    478
# SC    258
# SP      4
# TD      1
# dtype: int64

# %%
agrupado.plot.bar(color = 'gray')
# Out:
# <Axes: xlabel='Estado'>

# %%
#genero
agrupado = dataset.groupby(["Genero"]).size()

agrupado
# Out:
# Genero
# F              2
# Fem            1
# Feminino     461
# M              6
# Masculino    521
# dtype: int64

# %%
agrupado.plot.bar(color = 'gray')
# Out:
# <Axes: xlabel='Genero'>

# %%
#explorar colunas numéricas
#score
dataset["Score"].describe()
# Out:
# count    999.000000
# mean     648.621622
# std       98.264219
# min      376.000000
# 25%      580.000000
# 50%      653.000000
# 75%      721.000000
# max      850.000000
# Name: Score, dtype: float64

# %%
agrupado.plot.bar(color = 'gray')
# Out:
# <Axes: xlabel='Genero'>

# %%
#explorar colunas numéricas
#score
dataset["Idade"].describe()
# Out:
# count    999.000000
# mean      38.902903
# std       11.401912
# min      -20.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max      140.000000
# Name: Idade, dtype: float64

# %%
srn.boxplot(dataset['Score']).set_title('Score')
# Out:
# Text(0.5, 1.0, 'Score')

# %%
srn.histplot(dataset['Score']).set_title('Score')
# Out:
# Text(0.5, 1.0, 'Score')

# %%
#idade
dataset["Idade"].describe()
# Out:
# count    999.000000
# mean      38.902903
# std       11.401912
# min      -20.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max      140.000000
# Name: Idade, dtype: float64

# %%
srn.boxplot(dataset['Idade']).set_title('Idade')
# Out:
# Text(0.5, 1.0, 'Idade')

# %%
#saldo
dataset["Saldo"].describe()
# Out:
# count    9.990000e+02
# mean     7.164928e+06
# std      6.311840e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      8.958835e+06
# 75%      1.258684e+07
# max      2.117743e+07
# Name: Saldo, dtype: float64

# %%
srn.boxplot(dataset['Saldo']).set_title('Saldo')
# Out:
# Text(0.5, 1.0, 'Saldo')

# %%
srn.histplot(dataset['Saldo']).set_title('Saldo')
# Out:
# Text(0.5, 1.0, 'Saldo')

# %%
#salario
dataset["Salario"].describe()
# Out:
# count    9.920000e+02
# mean     3.528762e+07
# std      5.305800e+08
# min      9.677000e+03
# 25%      3.029011e+06
# 50%      8.703250e+06
# 75%      1.405213e+07
# max      1.193469e+10
# Name: Salario, dtype: float64

# %%
srn.boxplot(dataset['Salario']).set_title('Salario')
# Out:
# Text(0.5, 1.0, 'Salario')

# %%
srn.histplot(dataset['Salario']).set_title('Salario')
# Out:
# Text(0.5, 1.0, 'Salario')

# %%
#contamos valores NAN
#genero e salario
dataset.isnull().sum()
# Out:
# ID                0
# Score             0
# Estado            0
# Genero            8
# Idade             0
# Patrimonio        0
# Saldo             0
# Produtos          0
# TemCartCredito    0
# Ativo             0
# Salario           7
# Saiu              0
# dtype: int64

# %%
#salarios
#remover NAs e substituir pela mediana
dataset["Salario"].describe()
# Out:
# count    9.920000e+02
# mean     3.528762e+07
# std      5.305800e+08
# min      9.677000e+03
# 25%      3.029011e+06
# 50%      8.703250e+06
# 75%      1.405213e+07
# max      1.193469e+10
# Name: Salario, dtype: float64

# %%
mediana = sts.median(dataset["Salario"])
mediana
# Out:
# 70518.0

# %%
#substituir NAN por mediana
dataset.fillna({"Salario": mediana}, inplace=True)

# %%
#verificamos se NAN não existem mais
dataset['Salario'].isnull().sum()
# Out:
# 0

# %%
#genero
agrupado = dataset.groupby(["Genero"]).size()

agrupado
# Out:
# Genero
# F              2
# Fem            1
# Feminino     461
# M              6
# Masculino    521
# dtype: int64

# %%
#total de NAs
dataset['Genero'].isnull().sum()
# Out:
# 8

# %%
moda = sts.mode(dataset["Genero"])
moda
# Out:
# 'Masculino'

# %%
#preenche NAs com masculino (moda)
dataset.fillna({"Genero": moda}, inplace=True)

# %%
dataset['Genero'].isnull().sum()
# Out:
# 0

# %%
#padroniza de acordo com o dominio
dataset.loc[dataset['Genero'] == 'M', 'Genero'] = 'Masculino'
dataset.loc[dataset['Genero'].isin(['F', 'Fem']), 'Genero'] = 'Feminino'
#visualiza o resultado
agrupado = dataset.groupby(["Genero"]).size()
agrupado
# Out:
# Genero
# Feminino     464
# Masculino    535
# dtype: int64

# %%
#idades fora do dominio
dataset['Idade'].describe()
# Out:
# count    999.000000
# mean      38.902903
# std       11.401912
# min      -20.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max      140.000000
# Name: Idade, dtype: float64

# %%
#visualizar
dataset.loc[(dataset['Idade'] < 0) | (dataset['Idade'] > 120)]
# Out:
#       ID  Score Estado     Genero  Idade  Patrimonio     Saldo  Produtos  \
# 867  869    636     RS   Feminino    -10           1  17083346         1
# 984  986    773     RS  Masculino    -20           1  12453278         2
# 990  992    655     RS  Masculino    140           5     93147         2
#
#      TemCartCredito  Ativo     Salario  Saiu
# 867               1      0  11051028.0     1
# 984               0      1   1172357.0     0
# 990               1      0   6621413.0     0

# %%
#calcular a mediana
mediana = sts.median(dataset['Idade'])
mediana
# Out:
# 37

# %%
#substituir
dataset.loc[(dataset['Idade'] < 0) | (dataset['Idade'] > 120), 'Idade'] = mediana

# %%
#verificamos se ainda existem idades fora do dominio
dataset.loc[(dataset['Idade'] < 0) | (dataset['Idade'] > 120)]
# Out:
# Empty DataFrame
# Columns: [ID, Score, Estado, Genero, Idade, Patrimonio, Saldo, Produtos, TemCartCredito, Ativo, Salario, Saiu]
# Index: []

# %%
#dados duplicados, buscamos pelo ID
dataset[dataset.duplicated(['ID'], keep=False)]
# Out:
#     ID  Score Estado    Genero  Idade  Patrimonio    Saldo  Produtos  \
# 80  81    665     RS  Feminino     34           1  9664554         2
# 81  81    665     RS  Feminino     34           1  9664554         2
#
#     TemCartCredito  Ativo     Salario  Saiu
# 80               0      0  17141366.0     0
# 81               0      0  17141366.0     0

# %%
#excluimos pelo ID
dataset.drop_duplicates(subset='ID', keep='first', inplace=True)
#buscamos duplicados
dataset[dataset.duplicated(['ID'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [ID, Score, Estado, Genero, Idade, Patrimonio, Saldo, Produtos, TemCartCredito, Ativo, Salario, Saiu]
# Index: []

# %%
agrupado = dataset.groupby(["Estado"]).size()
agrupado
# Out:
# Estado
# PR    257
# RP      1
# RS    477
# SC    258
# SP      4
# TD      1
# dtype: int64

# %%
#atribuimos RS (moda)
dataset.loc[dataset['Estado'].isin(['RP', 'SP', 'TD']), 'Estado'] = 'RS'
agrupado = dataset.groupby(["Estado"]).size()
agrupado
# Out:
# Estado
# PR    257
# RS    483
# SC    258
# dtype: int64

# %%
#outliers em salario, vamos considerar 2 desvios padrão
desv = sts.stdev(dataset['Salario'])
desv
# Out:
# 528988918.4679201

# %%
#definir padrão como maior que 2 desvios padrão
#checamos se algum atende critério
dataset.loc[dataset['Salario'] >= 2 * desv]
# Out:
#       ID  Score Estado     Genero  Idade  Patrimonio     Saldo  Produtos  \
# 7      8    376     PR   Feminino     29           4  11504674         4
# 116  118    668     PR   Feminino     37           6   1678644         1
# 170  172    484     RS   Feminino     29           4  13011439         1
# 230  232    673     RS  Masculino     72           1         0         2
#
#      TemCartCredito  Ativo       Salario  Saiu
# 7                 1      0  1.193469e+10     1
# 116               1      0  1.156383e+10     0
# 170               1      0  1.640179e+09     0
# 230               0      1  1.119812e+09     0

# %%
#vamos atualizar salarios para mediana, calculamos
mediana = sts.median(dataset['Salario'])
mediana
# Out:
# 8637195.5

# %%
#atribuimos
dataset.loc[dataset['Salario'] >= 2 * desv, 'Salario'] = mediana
#checamos se algum atende criterio
dataset.loc[dataset['Salario'] >= 2 * desv]
# Out:
# Empty DataFrame
# Columns: [ID, Score, Estado, Genero, Idade, Patrimonio, Saldo, Produtos, TemCartCredito, Ativo, Salario, Saiu]
# Index: []

# %%
dataset.head()
# Out:
#    ID  Score Estado    Genero  Idade  Patrimonio     Saldo  Produtos  \
# 0   1    619     RS  Feminino     42           2         0         1
# 1   2    608     SC  Feminino     41           1   8380786         1
# 2   3    502     RS  Feminino     42           8   1596608         3
# 3   4    699     RS  Feminino     39           1         0         2
# 4   5    850     SC  Feminino     43           2  12551082         1
#
#    TemCartCredito  Ativo     Salario  Saiu
# 0               1      1  10134888.0     1
# 1               0      1  11254258.0     0
# 2               1      0  11393157.0     1
# 3               0      0   9382663.0     0
# 4               1      1    790841.0     0

# %%
dataset.shape
# Out:
# (998, 12)
