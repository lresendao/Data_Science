# %% [markdown]
# <a href="https://colab.research.google.com/github/lresendao/Data_Science/blob/Graphics%2C-Visualization-and-Dashboards/Graficos_Multiplos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importação das bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carregamento da base de dados
base = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Udemy/Python/Gráficos, Visualização e Dashboards/trees.csv')
base.shape
# Out:
# (31, 3)

# %%
#dados
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
#Criação do histograma, considerando somente o segundo atributo da base de dados e com duas divisões (bins)
#A variável 'h' armazena as faixas de valores de Height
h = np.histogram(base.iloc[:,1], bins = 6)
h
# Out:
# (array([4, 2, 5, 7, 9, 4]), array([63., 67., 71., 75., 79., 83., 87.]))

# %%
#Visualização do histograma com 6 divisões (bins)
plt.hist(base.iloc[:,1], bins = 6)
plt.title('Árvores')
plt.xlabel('Altura')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
#Histograma com a a linha de distribuição de frequência, com 6 divisões (bins)
#kde = linha de densidade
sns.histplot(base.iloc[:,1], kde=False, bins=6, color='blue').set(title='Árvores')
# Out:
# [Text(0.5, 1.0, 'Árvores')]

# %%
#densidade, método kdeplot para densidade
sns.kdeplot(base.iloc[:,1], color='blue').set(title='Árvores')
# Out:
# [Text(0.5, 1.0, 'Árvores')]

# %%
#densidade e histograma
sns.histplot(base.iloc[:,1], kde=True, bins=6, color='blue').set(title='Árvores')
# Out:
# [Text(0.5, 1.0, 'Árvores')]

# %%
#Gráfico de dispersão considerando o volume e a dispersão
plt.scatter(x=base.Girth, y=base.Volume, color = 'blue', facecolors = 'none', marker = '*')
plt.title('Árvores')
plt.xlabel('Volume')
plt.ylabel('Dispersão')
# Out:
# Text(0, 0.5, 'Dispersão')

# %%
#Gráfico de linha considerando o volume e o atributo "girth" - sem marker
plt.plot(base.Girth, base.Volume)
plt.title('Árvores')
plt.xlabel('Volume')
plt.ylabel('Dispersão')
# Out:
# Text(0, 0.5, 'Dispersão')

# %%
#Gráfico de dispersão com 'afastamento' dos dados (jitter)
#Gráfico de dispersão
sns.regplot(x=base.Girth,y=base.Volume, data = base, x_jitter=0.3, fit_reg = False)
# Out:
# <Axes: xlabel='Girth', ylabel='Volume'>

# %%
baseco2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Udemy/Python/Gráficos, Visualização e Dashboards/co2.csv')
baseco2.head()
# Out:
#   Plant    Type   Treatment  conc  uptake
# 0   Qn1  Quebec  nonchilled    95    16.0
# 1   Qn1  Quebec  nonchilled   175    30.4
# 2   Qn1  Quebec  nonchilled   250    34.8
# 3   Qn1  Quebec  nonchilled   350    37.2
# 4   Qn1  Quebec  nonchilled   500    35.3

# %%
#Criando duas variáveis para cada atributo (x = conc e y = uptake)
x = baseco2.conc
y = baseco2.uptake

# %%
#Retorna os valores únicos do atributo "Treatment"
unicos = list(set(baseco2.Treatment))
unicos
# Out:
# ['chilled', 'nonchilled']

# %%
#Percorre cada tipo de tratamento (chilled e nonchilled) e cria um gráfico de dispersão
for i in range(len(unicos)):
  indice = baseco2.Treatment == unicos[i]
  plt.scatter(x[indice], y[indice], label = unicos[i])
plt.legend(loc = 'lower right')

# %%
#Girth com Volume
plt.scatter(base.Girth, base.Volume)

# %%
#Girth com height
plt.scatter(base.Girth, base.Height)

# %%
#Height com volume
plt.scatter(base.Height, base.Volume, marker = '*')

# %%
#Histograma com volume
plt.hist(base.Volume)
# Out:
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <BarContainer object of 10 artists>)

# %%
#imprimindo juntos
# Criação de figura, no qual os gráficos serão posicionados
plt.figure(1)
plt.subplot(2,2,1)
plt.scatter(base.Girth, base.Volume)
plt.subplot(2,2,2)
plt.scatter(base.Girth, base.Height)
plt.subplot(2,2,3)
plt.scatter(base.Height, base.Volume, marker = '*')
plt.subplot(2,2,4)
plt.hist(base.Volume)
# Out:
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <BarContainer object of 10 artists>)

# %%
#Geração do boxplot
#patch_artist = True preenche, showfliers outliers
plt.boxplot(base.Volume, vert = False, showfliers = False, notch = True, patch_artist = True)
plt.title('Árvores')
plt.xlabel('Volume')
# Out:
# Text(0.5, 0, 'Volume')

# %%
#Dados por linha
plt.boxplot(base)
plt.title('Árvores')
plt.xlabel('Dados')
# Out:
# Text(0.5, 0, 'Dados')

# %%
#Geração de 3 boxplots, cada um mostrado informações diferentes
plt.boxplot(base.Volume, vert = False)
plt.boxplot(base.Girth, vert = False)
plt.boxplot(base.Height, vert = False)
plt.title('Árvores')
plt.xlabel('Dados')
# Out:
# Text(0.5, 0, 'Dados')

# %%
baseinsect = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Udemy/Python/Gráficos, Visualização e Dashboards/insect.csv')
baseinsect
# Out:
#     count spray
# 0      10     A
# 1       7     A
# 2      20     A
# 3      14     A
# 4      14     A
# ..    ...   ...
# 67     10     F
# 68     26     F
# 69     26     F
# 70     24     F
# 71     13     F
#
# [72 rows x 2 columns]

# %%
baseinsect.head()
# Out:
#    count spray
# 0     10     A
# 1      7     A
# 2     20     A
# 3     14     A
# 4     14     A

# %%
#Agrupamento de dos dados baseado no atributo 'spray', contando e somando os registros
agrupado_insect = baseinsect.groupby(['spray'])['count'].sum()
agrupado_insect
# Out:
# spray
# A    174
# B    184
# C     25
# D     59
# E     42
# F    200
# Name: count, dtype: int64

# %%
#Gráfico de barras
agrupado_insect.plot.bar(color = 'gray')
# Out:
# <Axes: xlabel='spray'>

# %%
#cores
agrupado_insect.plot.bar(color = ['blue', 'yellow', 'red' ,'green', 'pink', 'orange'])
# Out:
# <Axes: xlabel='spray'>

# %%
#Gráfico de pizza
agrupado_insect.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
#Com legenda
agrupado_insect.plot.pie(legend = True)
# Out:
# <Axes: ylabel='count'>

# %%
#Visualização de um boxplot
sns.boxplot(data = base.Volume, orient = 'v').set_title('Árvores')
# Out:
# Text(0.5, 1.0, 'Árvores')

# %%
#Visualização de vários boxplots na mesma imagem
sns.boxplot(data = base)
# Out:
# <Axes: >

# %%
#Histograma com 10 divisões (bins) e com gráfico de densidade (kernel density - suaviação)
#stat: count, frequency, probability, percent, density
sns.histplot(base.Volume, color='blue', kde=True, bins=10, stat='density').set(title='Volume')
# Out:
# [Text(0.5, 1.0, 'Volume')]

# %%
#Carregamento de outra base de dados
base_chicken = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Udemy/Python/Gráficos, Visualização e Dashboards/chicken.csv')
base_chicken.head()
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean

# %%
#Criação de novo dataframe agrupando o atributo 'feed'
agrupado_chicken = base_chicken.groupby(['feed'])['weight'].sum()
agrupado_chicken
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %%
#Novo dataframe somente para testar os filtros do pandas
teste = base_chicken.loc[base_chicken['feed'] == 'horsebean']
teste
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean
# 5     168  horsebean
# 6     108  horsebean
# 7     124  horsebean
# 8     143  horsebean
# 9     140  horsebean

# %%
#Histograma considerando somente o valor 'horsebean'
#Apenas o grafico de densidade neste caso
sns.kdeplot(base_chicken.loc[base_chicken['feed'] == 'horsebean'].weight).set(title='horsebean')
# Out:
# [Text(0.5, 1.0, 'horsebean')]

# %%
#Histograma considerando somente o valor 'casein'
sns.histplot(base_chicken.loc[base_chicken['feed'] == 'casein'].weight, kde=True).set(title='casein')
# Out:
# [Text(0.5, 1.0, 'casein')]

# %%
#Histograma considerando somente o valor 'linseed'
sns.histplot(base_chicken.loc[base_chicken['feed'] == 'linseed'].weight, kde=True).set(title='linseed')
# Out:
# [Text(0.5, 1.0, 'linseed')]

# %%
#Histograma considerando somente o valor 'meatmeal'
sns.histplot(base_chicken.loc[base_chicken['feed'] == 'meatmeal'].weight, kde=True).set(title='meatmeal')
# Out:
# [Text(0.5, 1.0, 'meatmeal')]

# %%
#Histograma considerando somente o valor 'soybean'
sns.histplot(base_chicken.loc[base_chicken['feed'] == 'soybean'].weight, kde=True).set(title='soybean')

# %%
#Histograma considerando somente o valor 'sunflower'
sns.histplot(base_chicken.loc[base_chicken['feed'] == 'sunflower'].weight, kde=True).set(title='sunflower')
# Out:
# [Text(0.5, 1.0, 'sunflower')]

# %%
#impressão em gráfico 2 x 3 - 3 linhas 2 colunas
plt.figure()
plt.subplot(3,2,1)
sns.histplot(base_chicken.loc[base_chicken['feed'] == 'horsebean'].weight, kde=True).set(title='horsebean')
plt.subplot(3,2,2)
sns.histplot(base_chicken.loc[base_chicken['feed'] == 'casein'].weight, kde=True).set(title='casein')
plt.subplot(3,2,3)
sns.histplot(base_chicken.loc[base_chicken['feed'] == 'linseed'].weight, kde=True).set(title='linseed')
plt.subplot(3,2,4)
sns.histplot(base_chicken.loc[base_chicken['feed'] == 'meatmeal'].weight, kde=True).set(title='meatmeal')
plt.subplot(3,2,5)
sns.histplot(base_chicken.loc[base_chicken['feed'] == 'soybean'].weight, kde=True).set(title='soybean')
plt.subplot(3,2,6)
sns.histplot(base_chicken.loc[base_chicken['feed'] == 'sunflower'].weight, kde=True).set(title='sunflower')
#ajusta o layout para não haver sobreposição
plt.tight_layout()
